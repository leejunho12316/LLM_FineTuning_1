# %% [markdown]
# #계획
#
# ## 서울시 응답소 Web Crawling
#
# https://eungdapso.seoul.go.kr/req/mayor_hope/mayor_hope.do
# 서울시 응답소 - 시장에게 알린다 탭에 올라와 있는 '공개된 민원' Web Crawling

# %% [markdown]
# 주소 구성
#
# 주소 https://eungdapso.seoul.go.kr/req/mayor_hope/mayor_hope.do?cp=2&sv=&sk=&rceptNo_enc=&startDt=2024-04-09&endDt=2026-04-09
#
# cp : 검색결과 쪽수
# startDT, endDT : 검색 시작일-끝일.
# - 시작일과 끝일의 길이는 2년을 넘어갈 수 없음 ex) 20240401-20260401 가능. 20240401-20260402 불가능.
# - 실제 데이터는 2001년 5월부터 현재까지 있음.
#
# 목표 : 10,000행

# %%
import requests
from bs4 import BeautifulSoup
import re, time, random

BASE_URL = "https://eungdapso.seoul.go.kr/req/mayor_hope/mayor_hope.do"
DETAIL_URL = "https://eungdapso.seoul.go.kr/req/mayor_hope/mayor_hope_vie.do"

session = requests.Session()
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"}

# 리스트 페이지 전체 html 가져오기
def get_list_page(cp: int, start_dt: str, end_dt: str):
    params = {"cp": cp, "sv": "", "sk": "", "rceptNo_enc": "",
              "startDt": start_dt, "endDt": end_dt}
    res = session.get(BASE_URL, params=params, headers=headers)
    return res.text

# ── 리스트 페이지 전체 html에서 총 페이지 수 추출
def parse_last_page(html: str) -> int:
    match = re.search(r'var lastCp = (\d+);', html)
    return int(match.group(1)) if match else 1

# ── 현제 리스트 페이지에 보이는 글(rceptNo_enc) 리스트 추출
def parse_rceptNo_list(html: str) -> list[str]:
    # onView('...') 패턴에서 추출
    return re.findall(r"onView\('([^']+)'\)", html)

# 상세 페이지 html 가져오기 : rceptNo_enc = 글 ID
# def get_detail_page(rceptNo_enc: str):
#     data = {
#         "rceptNo_enc": rceptNo_enc,
#     }
#     res = session.post(DETAIL_URL, data=data, headers=headers) #POST로 rceptNo_enc 전송
#     return BeautifulSoup(res.text, "html.parser")

def get_detail_page(rceptNo_enc: str):
    data = {"rceptNo_enc": rceptNo_enc}
    detail_headers = {**headers, "Connection": "close"}
    res = session.post(DETAIL_URL, data=data, headers=detail_headers)
    return BeautifulSoup(res.text, "html.parser")

# ── 5. 상세 페이지 html에서 데이터 파싱
def parse_details(soup) -> dict:

    # <br> 태그를 \n으로 바꾸는 헬퍼
    def br_to_newline(tag):
        for br in tag.find_all("br"):
            br.replace_with("\n")
        return tag.get_text()

    # 제목
    title_tag = soup.select_one("h3.sclinkage_title")
    title = title_tag.get_text(strip=True) if title_tag else ""

    # 날짜 (첫 번째 sclinkage_evalue)
    date_tag = soup.select("span.sclinkage_evalue")
    date_val = date_tag[0].get_text(strip=True) if date_tag else ""

    # 상담내용 / 답변내용 — indent_vtit 텍스트로 구분
    question, answer = "", ""
    for block in soup.select("div.indent_vitem"):
        label = block.select_one("p.indent_vtit")
        content = block.select_one("span.rp_indata")
        if not label or not content:
            continue
        text = br_to_newline(content).strip()
        if "상담" in label.get_text():
            question = text
        elif "답변" in label.get_text():
            answer = text

    return {"title": title, "Date": date_val, "Question": question, "Answer": answer}

# %% [markdown]
# 시험

# %%
start_dt = '2001-05-01'
end_dt = '2002-01-01'

#전체 리스트
page_1 = get_list_page(cp = 1, start_dt = start_dt, end_dt = end_dt)
last_page = parse_last_page(page_1)
rceptNo_list = parse_rceptNo_list(page_1)

#상세 페이지
page_1_1 = get_detail_page(rceptNo_list[0])
parse_details(page_1_1)
# Out:
# {'title': '시장님께',
#  'Date': '2002-01-01',
#  'Question': '서울특별시 시장님 안녕하십니까\n 저는 구미시에 사는 이○○이라고합니다\n 건의할께있어서 이렇게 글을 올립니다\n 도서상품권에 관한것입니다\n 도서상품권은 돈을 주고 사는 것인데\n 왜 도서상품권은 20프로밖에 환불인안돼조\n 그러면 차라리 돈주고 책을 사는게났겟습니다\n 도서상품권은 선물용 이라고도그러시는대\n 누가 쓰던지 마찬가지 아닙니까\n 도서상품권\n 아무런필요가 없다고 생각합니다',
#  'Answer': '안녕하십니까? 서울시장 고 건 입니다.\n ○○○님께서는 도서상품권의 잔여환급에 대해 문의하셨습니다.\n 현재 상품권 관련업은 자유업으로 현행법상 제재수단은 없으며 상품권 잔액환급금액에 대한 기준은 "소비자피해보상규정"에 의해 금액상품권의 잔액환급비율 금액이상에 상당하는 물품 또는 용역을 제공받고 그 잔액을 환급할 수 있도록 하고 있습니다.\n 잔액환급비율은 상품권의 권면금액이 1만원 초과일 경우는 100분의 60, 상품권의 권면금액이 1만원이하일 경우는 100분의 80입니다.\n ○○○님의 궁금한 사항에 대해 도움이 되었기를 바라며, 기타 소비자피해와 관련하여 궁금하신 사항이 있으시면 서울시 소비자정보센터(733-9898, 739-9898)로 연락주시면 친절히 도와드리겠습니다.\n 추운 날씨에 건강조심하시기 바랍니다.\n \n 2002. 1. 7\n 서울시장 고 건 드림'}

# %% [markdown]
# 검색 기간 설정

# %%
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta

#데이터가 존재하는 2001-05-01부터 현재까지
#검색 기간 설정 제약조건인 2년에 맞도록 기간 구성.
def generate_date_ranges(start: date, end: date):
    # 분기 시작월: 1, 4, 7, 10
    quarter_starts = [1, 4, 7, 10]

    ranges = []
    cur = end

    while cur >= start:
        # 현재 날짜가 속한 분기 시작일 계산
        q_month = ((cur.month - 1) // 3) * 3 + 1
        q_start = date(cur.year, q_month, 1)
        q_start = max(q_start, start)  # start보다 앞으로 가지 않도록

        ranges.append((q_start.strftime("%Y-%m-%d"), cur.strftime("%Y-%m-%d")))

        # 다음 반복: 해당 분기 시작일 하루 전
        cur = q_start - timedelta(days=1)

    return ranges

generate_date_ranges(date(2001,4,1), date(2026,4,9))
# Out:
# [('2026-04-01', '2026-04-09'),
#  ('2026-01-01', '2026-03-31'),
#  ('2025-10-01', '2025-12-31'),
#  ('2025-07-01', '2025-09-30'),
#  ('2025-04-01', '2025-06-30'),
#  ('2025-01-01', '2025-03-31'),
#  ('2024-10-01', '2024-12-31'),
#  ('2024-07-01', '2024-09-30'),
#  ('2024-04-01', '2024-06-30'),
#  ('2024-01-01', '2024-03-31'),
#  ('2023-10-01', '2023-12-31'),
#  ('2023-07-01', '2023-09-30'),
#  ('2023-04-01', '2023-06-30'),
#  ('2023-01-01', '2023-03-31'),
#  ('2022-10-01', '2022-12-31'),
#  ('2022-07-01', '2022-09-30'),
#  ('2022-04-01', '2022-06-30'),
#  ('2022-01-01', '2022-03-31'),
#  ('2021-10-01', '2021-12-31'),
#  ('2021-07-01', '2021-09-30'),
#  ('2021-04-01', '2021-06-30'),
#  ('2021-01-01', '2021-03-31'),
#  ('2020-10-01', '2020-12-31'),
#  ('2020-07-01', '2020-09-30'),
#  ('2020-04-01', '2020-06-30'),
#  ('2020-01-01', '2020-03-31'),
#  ('2019-10-01', '2019-12-31'),
#  ('2019-07-01', '2019-09-30'),
#  ('2019-04-01', '2019-06-30'),
#  ('2019-01-01', '2019-03-31'),
#  ('2018-10-01', '2018-12-31'),
#  ('2018-07-01', '2018-09-30'),
#  ('2018-04-01', '2018-06-30'),
#  ('2018-01-01', '2018-03-31'),
#  ('2017-10-01', '2017-12-31'),
#  ('2017-07-01', '2017-09-30'),
#  ('2017-04-01', '2017-06-30'),
#  ('2017-01-01', '2017-03-31'),
#  ('2016-10-01', '2016-12-31'),
#  ('2016-07-01', '2016-09-30'),
#  ('2016-04-01', '2016-06-30'),
#  ('2016-01-01', '2016-03-31'),
#  ('2015-10-01', '2015-12-31'),
#  ('2015-07-01', '2015-09-30'),
#  ('2015-04-01', '2015-06-30'),
#  ('2015-01-01', '2015-03-31'),
#  ('2014-10-01', '2014-12-31'),
#  ('2014-07-01', '2014-09-30'),
#  ('2014-04-01', '2014-06-30'),
#  ('2014-01-01', '2014-03-31'),
#  ('2013-10-01', '2013-12-31'),
#  ('2013-07-01', '2013-09-30'),
#  ('2013-04-01', '2013-06-30'),
#  ('2013-01-01', '2013-03-31'),
#  ('2012-10-01', '2012-12-31'),
#  ('2012-07-01', '2012-09-30'),
#  ('2012-04-01', '2012-06-30'),
#  ('2012-01-01', '2012-03-31'),
#  ('2011-10-01', '2011-12-31'),
#  ('2011-07-01', '2011-09-30'),
#  ('2011-04-01', '2011-06-30'),
#  ('2011-01-01', '2011-03-31'),
#  ('2010-10-01', '2010-12-31'),
#  ('2010-07-01', '2010-09-30'),
#  ('2010-04-01', '2010-06-30'),
#  ('2010-01-01', '2010-03-31'),
#  ('2009-10-01', '2009-12-31'),
#  ('2009-07-01', '2009-09-30'),
#  ('2009-04-01', '2009-06-30'),
#  ('2009-01-01', '2009-03-31'),
#  ('2008-10-01', '2008-12-31'),
#  ('2008-07-01', '2008-09-30'),
#  ('2008-04-01', '2008-06-30'),
#  ('2008-01-01', '2008-03-31'),
#  ('2007-10-01', '2007-12-31'),
#  ('2007-07-01', '2007-09-30'),
#  ('2007-04-01', '2007-06-30'),
#  ('2007-01-01', '2007-03-31'),
#  ('2006-10-01', '2006-12-31'),
#  ('2006-07-01', '2006-09-30'),
#  ('2006-04-01', '2006-06-30'),
#  ('2006-01-01', '2006-03-31'),
#  ('2005-10-01', '2005-12-31'),
#  ('2005-07-01', '2005-09-30'),
#  ('2005-04-01', '2005-06-30'),
#  ('2005-01-01', '2005-03-31'),
#  ('2004-10-01', '2004-12-31'),
#  ('2004-07-01', '2004-09-30'),
#  ('2004-04-01', '2004-06-30'),
#  ('2004-01-01', '2004-03-31'),
#  ('2003-10-01', '2003-12-31'),
#  ('2003-07-01', '2003-09-30'),
#  ('2003-04-01', '2003-06-30'),
#  ('2003-01-01', '2003-03-31'),
#  ('2002-10-01', '2002-12-31'),
#  ('2002-07-01', '2002-09-30'),
#  ('2002-04-01', '2002-06-30'),
#  ('2002-01-01', '2002-03-31'),
#  ('2001-10-01', '2001-12-31'),
#  ('2001-07-01', '2001-09-30'),
#  ('2001-04-01', '2001-06-30')]

# %% [markdown]
# 크롤링 main 파이프라인 구성, 실행

# %%
import json

def crawl(start_dt, end_dt):
  results = []

  html = get_list_page(cp=1, start_dt=start_dt, end_dt=end_dt)
  last_page = parse_last_page(html)
  print(f"[{start_dt} ~ {end_dt}] 총 {last_page}페이지")
  time.sleep(random.uniform(2.0, 3.5))

  for cp in range(1, last_page + 1):
    page_html = get_list_page(cp, start_dt, end_dt)
    time.sleep(random.uniform(0.8, 1.5))

    for rceptNo_enc in parse_rceptNo_list(page_html):
      detail_html = get_detail_page(rceptNo_enc)
      data = parse_details(detail_html)
      data["rceptNo_enc"] = rceptNo_enc

      results.append(data)
      time.sleep(random.uniform(1.0, 2.0))

    print(f"  {cp}/{last_page} 페이지 완료")

  filename = f"mayor_hope_{start_dt}_{end_dt}.json"
  with open(filename, "w", encoding="utf-8") as f:
      json.dump(results, f, ensure_ascii=False, indent=2)
  print(f"  → {filename} 저장 완료 ({len(results)}건)\n")

# %%
for start_dt, end_dt in generate_date_ranges(date(2001,4,1), date(2017,12,31)):
  crawl(start_dt, end_dt)
# Out:
# [2017-10-01 ~ 2017-12-31] 총 35페이지
#   1/35 페이지 완료
#   2/35 페이지 완료
#   3/35 페이지 완료
#   4/35 페이지 완료
#   5/35 페이지 완료
#   6/35 페이지 완료
#   7/35 페이지 완료
#   8/35 페이지 완료
#   9/35 페이지 완료
#   10/35 페이지 완료
#   11/35 페이지 완료
#   12/35 페이지 완료
#   13/35 페이지 완료
#   14/35 페이지 완료
#   15/35 페이지 완료
#   16/35 페이지 완료
#   17/35 페이지 완료
#   18/35 페이지 완료
#   19/35 페이지 완료
#   20/35 페이지 완료
#   21/35 페이지 완료
#   22/35 페이지 완료
#   23/35 페이지 완료
#   24/35 페이지 완료
#   25/35 페이지 완료
#   26/35 페이지 완료
#   27/35 페이지 완료
#   28/35 페이지 완료
#   29/35 페이지 완료
#   30/35 페이지 완료
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:903, in HTTPResponse._error_catcher(self)
#     902 try:
# --> 903     yield
#     905 except SocketTimeout as e:
#     906     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     907     # there is yet no clean way to get at it from this context.
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1421, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1420         break
# -> 1421     chunk = self._handle_chunk(amt)
#    1422 decoded = self._decode(
#    1423     chunk,
#    1424     decode_content=decode_content,
#    1425     flush_decoder=False,
#    1426     max_length=amt,
#    1427 )
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1354, in HTTPResponse._handle_chunk(self, amt)
#    1353 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1354     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1355     self.chunk_left = self.chunk_left - amt
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:644, in HTTPResponse._safe_read(self, amt)
#     643 if len(data) < amt:
# --> 644     raise IncompleteRead(data, amt-len(data))
#     645 return data
#
# IncompleteRead: IncompleteRead(9034 bytes read, 1206 more expected)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\models.py:822, in Response.iter_content.<locals>.generate()
#     821 try:
# --> 822     yield from self.raw.stream(chunk_size, decode_content=True)
#     823 except ProtocolError as e:
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1397, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1392     raise BodyNotHttplibCompatible(
#    1393         "Body should be http.client.HTTPResponse like. "
#    1394         "It should have have an fp attribute which returns raw chunks."
#    1395     )
# -> 1397 with self._error_catcher():
#    1398     # Don't bother reading the body of a HEAD request.
#    1399     if self._original_response and is_response_to_head(self._original_response):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:930, in HTTPResponse._error_catcher(self)
#     929 except (HTTPException, OSError) as e:
# --> 930     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     932 # If no exception is thrown, we should avoid cleaning up
#     933 # unnecessarily.
#
# ProtocolError: ('Connection broken: IncompleteRead(9034 bytes read, 1206 more expected)', IncompleteRead(9034 bytes read, 1206 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[11], line 2
#       1 for start_dt, end_dt in generate_date_ranges(date(2001,4,1), date(2017,12,31)):
# ----> 2   crawl(start_dt, end_dt)
#
# Cell In[6], line 16, in crawl(start_dt, end_dt)
#      12     page_html = get_list_page(cp, start_dt, end_dt)
#      13     time.sleep(random.uniform(0.8, 1.5))
#      14
#      15     for rceptNo_enc in parse_rceptNo_list(page_html):
# ---> 16       detail_html = get_detail_page(rceptNo_enc)
#      17       data = parse_details(detail_html)
#      18       data["rceptNo_enc"] = rceptNo_enc
#      19
#
# Cell In[3], line 33, in get_detail_page(rceptNo_enc)
#      29 def get_detail_page(rceptNo_enc: str):
#      30     data = {
#      31         "rceptNo_enc": rceptNo_enc,
#      32     }
# ---> 33     res = session.post(DETAIL_URL, data=data, headers=headers) #POST로 rceptNo_enc 전송
#      34     return BeautifulSoup(res.text, "html.parser")
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\sessions.py:640, in Session.post(self, url, data, json, **kwargs)
#     629 def post(self, url, data=None, json=None, **kwargs):
#     630     r"""Sends a POST request. Returns :class:`Response` object.
#     631
#     632     :param url: URL for the new :class:`Request` object.
#    (...)    637     :rtype: requests.Response
#     638     """
# --> 640     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587 send_kwargs = {
#     588     "timeout": timeout,
#     589     "allow_redirects": allow_redirects,
#     590 }
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\sessions.py:749, in Session.send(self, request, **kwargs)
#     746         pass
#     748 if not stream:
# --> 749     r.content
#     751 return r
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\models.py:904, in Response.content(self)
#     902         self._content = None
#     903     else:
# --> 904         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     906 self._content_consumed = True
#     907 # don't need to release the connection; that's been handled by urllib3
#     908 # since we exhausted the data.
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\models.py:824, in Response.iter_content.<locals>.generate()
#     822     yield from self.raw.stream(chunk_size, decode_content=True)
#     823 except ProtocolError as e:
# --> 824     raise ChunkedEncodingError(e)
#     825 except DecodeError as e:
#     826     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(9034 bytes read, 1206 more expected)', IncompleteRead(9034 bytes read, 1206 more expected))

# %%
import json, os
from requests.exceptions import ChunkedEncodingError, ConnectionError, Timeout

RETRY_EXCEPTIONS = (ChunkedEncodingError, ConnectionError, Timeout)

def crawl(start_dt, end_dt):
    filename  = f"mayor_hope_{start_dt}_{end_dt}.json"
    ckpt_file = filename + ".ckpt"

    # .ckpt 없이 JSON만 있으면 → 완료된 파일, SKIP
    if os.path.exists(filename) and not os.path.exists(ckpt_file):
        with open(filename, encoding="utf-8") as f:
            existing = json.load(f)
        print(f"[SKIP] {filename} 완료 ({len(existing)}건)")
        return

    # .ckpt 있으면 → 이전에 중단된 파일, 이어받기
    if os.path.exists(ckpt_file):
        with open(ckpt_file, encoding="utf-8") as f:
            ckpt = json.load(f)
        with open(filename, encoding="utf-8") as f:
            results = json.load(f)
        start_cp = ckpt["last_cp"] + 1
        last_page = ckpt["last_page"]
        print(f"[RESUME] {filename} — {start_cp}페이지부터 재개 (이미 {len(results)}건)")
    else:
        results = []
        html = get_list_page(cp=1, start_dt=start_dt, end_dt=end_dt)
        last_page = parse_last_page(html)
        start_cp = 1
        print(f"[{start_dt} ~ {end_dt}] 총 {last_page}페이지")
        time.sleep(random.uniform(2.0, 3.5))

    for cp in range(start_cp, last_page + 1):
        for attempt in range(1, 11):  # 최대 10회 재시도
            try:
                page_html = get_list_page(cp, start_dt, end_dt)
                time.sleep(random.uniform(0.8, 1.5))

                page_results = []
                for rceptNo_enc in parse_rceptNo_list(page_html):
                    detail_html = get_detail_page(rceptNo_enc)

                    data = parse_details(detail_html)
                    data["rceptNo_enc"] = rceptNo_enc
                    page_results.append(data)
                    time.sleep(random.uniform(4.0, 6.0))

                results.extend(page_results)
                break

            except RETRY_EXCEPTIONS as e:
                wait = min(10 * (2 ** (attempt - 1)), 300)
                print(f"  [오류] {cp}/{last_page}페이지 — {type(e).__name__}")

                if attempt < 10:
                    print(f"         세션 재생성 후 {wait}초 대기, {cp}페이지 재시도 ({attempt}/10)")
                    global session
                    session = requests.Session()
                    time.sleep(wait)
                else:
                    print(f"         재시도 횟수 초과 — 현재까지 저장 후 다음 분기로 넘어감")
                    # 저장 후 다음 분기로 (전체 중단 X)
                    with open(filename, "w", encoding="utf-8") as f:
                        json.dump(results, f, ensure_ascii=False, indent=2)
                    with open(ckpt_file, "w", encoding="utf-8") as f:
                        json.dump({"last_cp": cp - 1, "last_page": last_page}, f)
                    return  # 이 분기 종료, 다음 분기 계속

        # 페이지 성공마다 JSON + ckpt 저장
        with open(filename, "w", encoding="utf-8") as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
        with open(ckpt_file, "w", encoding="utf-8") as f:
            json.dump({"last_cp": cp, "last_page": last_page}, f)
        print(f"  {cp}/{last_page} 페이지 완료 (누적 {len(results)}건)")

    # 모든 페이지 완료 → ckpt 삭제 (완료 표시)
    os.remove(ckpt_file)
    print(f"  → {filename} 최종 저장 완료 ({len(results)}건)\n")

for start_dt, end_dt in generate_date_ranges(date(2005,4,1), date(2011,12,31)):
    crawl(start_dt, end_dt)
# Out:
# [RESUME] mayor_hope_2011-10-01_2011-12-31.json — 17페이지부터 재개 (이미 160건)
#   [오류] 17/67페이지 — ChunkedEncodingError
#          세션 재생성 후 10초 대기, 17페이지 재시도 (1/10)
#   [오류] 17/67페이지 — ConnectionError
#          세션 재생성 후 20초 대기, 17페이지 재시도 (2/10)
#   [오류] 17/67페이지 — ConnectionError
#          세션 재생성 후 40초 대기, 17페이지 재시도 (3/10)
#   [오류] 17/67페이지 — ChunkedEncodingError
#          세션 재생성 후 80초 대기, 17페이지 재시도 (4/10)
#   [오류] 17/67페이지 — ChunkedEncodingError
#          세션 재생성 후 160초 대기, 17페이지 재시도 (5/10)
#   [오류] 17/67페이지 — ChunkedEncodingError
#          세션 재생성 후 300초 대기, 17페이지 재시도 (6/10)
#   [오류] 17/67페이지 — ChunkedEncodingError
#          세션 재생성 후 300초 대기, 17페이지 재시도 (7/10)
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:903, in HTTPResponse._error_catcher(self)
#     902 try:
# --> 903     yield
#     905 except SocketTimeout as e:
#     906     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     907     # there is yet no clean way to get at it from this context.
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1421, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1420         break
# -> 1421     chunk = self._handle_chunk(amt)
#    1422 decoded = self._decode(
#    1423     chunk,
#    1424     decode_content=decode_content,
#    1425     flush_decoder=False,
#    1426     max_length=amt,
#    1427 )
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1354, in HTTPResponse._handle_chunk(self, amt)
#    1353 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1354     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1355     self.chunk_left = self.chunk_left - amt
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\http\client.py:644, in HTTPResponse._safe_read(self, amt)
#     643 if len(data) < amt:
# --> 644     raise IncompleteRead(data, amt-len(data))
#     645 return data
#
# IncompleteRead: IncompleteRead(7586 bytes read, 2654 more expected)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\models.py:822, in Response.iter_content.<locals>.generate()
#     821 try:
# --> 822     yield from self.raw.stream(chunk_size, decode_content=True)
#     823 except ProtocolError as e:
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:1397, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1392     raise BodyNotHttplibCompatible(
#    1393         "Body should be http.client.HTTPResponse like. "
#    1394         "It should have have an fp attribute which returns raw chunks."
#    1395     )
# -> 1397 with self._error_catcher():
#    1398     # Don't bother reading the body of a HEAD request.
#    1399     if self._original_response and is_response_to_head(self._original_response):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\urllib3\response.py:930, in HTTPResponse._error_catcher(self)
#     929 except (HTTPException, OSError) as e:
# --> 930     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     932 # If no exception is thrown, we should avoid cleaning up
#     933 # unnecessarily.
#
# ProtocolError: ('Connection broken: IncompleteRead(7586 bytes read, 2654 more expected)', IncompleteRead(7586 bytes read, 2654 more expected))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[28], line 60, in crawl(start_dt, end_dt)
#      58                     global session
#      59                     session = requests.Session()
# ---> 60                     time.sleep(wait)
#      61                 else:
#
# Cell In[27], line 39, in get_detail_page(rceptNo_enc)
#      37     data = {"rceptNo_enc": rceptNo_enc}
#      38     detail_headers = {**headers, "Connection": "close"}
# ---> 39     res = session.post(DETAIL_URL, data=data, headers=detail_headers)
#      40     return BeautifulSoup(res.text, "html.parser")
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\sessions.py:640, in Session.post(self, url, data, json, **kwargs)
#     630 r"""Sends a POST request. Returns :class:`Response` object.
#     631
#     632 :param url: URL for the new :class:`Request` object.
#    (...)    637 :rtype: requests.Response
#     638 """
# --> 640 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\sessions.py:749, in Session.send(self, request, **kwargs)
#     748 if not stream:
# --> 749     r.content
#     751 return r
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\models.py:904, in Response.content(self)
#     903     else:
# --> 904         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     906 self._content_consumed = True
#
# File ~\PycharmProjects\LLM_FineTuning_1\.venv\Lib\site-packages\requests\models.py:824, in Response.iter_content.<locals>.generate()
#     823 except ProtocolError as e:
# --> 824     raise ChunkedEncodingError(e)
#     825 except DecodeError as e:
#
# ChunkedEncodingError: ('Connection broken: IncompleteRead(7586 bytes read, 2654 more expected)', IncompleteRead(7586 bytes read, 2654 more expected))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 82
#      78     os.remove(ckpt_file)
#      79     print(f"  → {filename} 최종 저장 완료 ({len(results)}건)\n")
#      80
#      81 for start_dt, end_dt in generate_date_ranges(date(2005,4,1), date(2011,12,31)):
# ---> 82     crawl(start_dt, end_dt)
#
# Cell In[28], line 60, in crawl(start_dt, end_dt)
#      56                 if attempt < 10:
#      57                     print(f"         세션 재생성 후 {wait}초 대기, {cp}페이지 재시도 ({attempt}/10)")
#      58                     global session
#      59                     session = requests.Session()
# ---> 60                     time.sleep(wait)
#      61                 else:
#      62                     print(f"         재시도 횟수 초과 — 현재까지 저장 후 다음 분기로 넘어감")
#      63                     # 저장 후 다음 분기로 (전체 중단 X)
#
# KeyboardInterrupt:

# %%
import json, glob, pandas as pd

files = sorted(glob.glob("./1.WebCrawling/mayor_hope_*.json"))
files = [f for f in files if not f.endswith(".ckpt")]

all_data = []
for f in files:
    with open(f, encoding="utf-8") as fp:
        all_data.extend(json.load(fp))

df = pd.DataFrame(all_data)
df.to_csv("mayor_hope.csv", index=False, encoding="utf-8-sig")
print(f"저장 완료: mayor_hope.csv ({len(df)}건)")
# Out:
# 저장 완료: mayor_hope.csv (13540건)
